# %%
# %%capture
# !conda install -y -c rdkit rdkit

# %%
# %%writefile normalize_inchis.py

from tqdm import tqdm
from rdkit import Chem
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')
from pathlib import Path

def normalize_inchi(inchi):
    try:
        mol = Chem.MolFromInchi(inchi)
    except:
        pass
    if mol is None:
        return inchi, 0
    else:
        try:   
            new_inchi = Chem.MolToInchi(mol)
        except: return inchi, 0
        if new_inchi == inchi:
            return new_inchi, 1
        else:
            return new_inchi, 2
        
submission_name = './final_sub.csv'
norm_path = Path('./submission.csv')

# Do the job
N = norm_path.read_text().count('\n') if norm_path.exists() else 0
print(N, 'number of predictions already normalized')

r = open(submission_name, 'r')
write_mode = 'w' if N == 0 else 'a'
w = open(str(norm_path), write_mode, buffering=1)

for _ in range(N):
    r.readline()
line = r.readline()  # this line is the header or is where it died last time
w.write(line)

pbar = tqdm()
while True:
    line = r.readline()
    if not line:
        break  # done
  
    image_id = line.split(',')[0]
    inchi = ','.join(line[:-1].split(',')[1:]).replace('"','')
    all_inchi = inchi.split(',|')
    normed = []
    scores = []
    final_inchi = None
    for i in all_inchi:
        inchi_norm, score = normalize_inchi(i)
        normed += [inchi_norm]
        scores += [score]
        if score == 1:
            final_inchi = inchi_norm
            break
    
    if final_inchi is None:
        # Check for Normalized values at least.
        for i in range(len(scores)):
            if scores[i] == 2:
                final_inchi = normed[i]
                break # keep order of preference.
    # Give up
    if final_inchi is None:
        final_inchi = normed[0] # Take the Best you've got.

    w.write(f'{image_id},"{final_inchi}"\n')
    pbar.update(1)

r.close()
w.close()
# Out:
# Writing normalize_inchis.py

# %% [markdown]
# # Concatenate the Sharded Predictions

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm 
sample_sub = pd.read_csv('../input/version22/submission.csv')

# %%
csv = pd.read_csv('../input/beamsearched/submission.csv')

to_be_df = {"image_id": csv.image_id.tolist(), 'InChI': csv.InChI.values.tolist()}
ids_exist = csv.image_id.values
not_in = sample_sub[np.logical_not(sample_sub.image_id.isin(ids_exist))]
to_be_df['image_id'] += not_in['image_id'].values.tolist()
to_be_df['InChI'] += not_in['InChI'].values.tolist() # Fill with Best, Not Beam Searched submission
#values_in = sample_sub[sample_sub.image_id.isin(ids_exist)].sort_values('image_id').reset_index(drop = True)
# Sort and Save
to_be_df = pd.DataFrame(to_be_df).sort_values('image_id').reset_index(drop = True)
to_be_df.to_csv('./padded_submission.csv', index = False)

# %%
import pandas as pd
sample_sub = pd.read_csv('../input/version22/submission.csv')
final_prediction_paths = ['./padded_submission.csv', '../input/version22/submission.csv', '../input/version16/submission.csv', '../input/pseudolabels-bms/concat_submission.csv'] # Ordered in the preference you want
CSV = None
cur_num = 1
for path in final_prediction_paths:
    df = pd.read_csv(path)
    if CSV is None:
        CSV = df
        CSV[f'InChI_{cur_num}'] = CSV['InChI']
        del CSV['InChI']
        cur_num += 1
    else:
        # add column
        CSV[f'InChI_{cur_num}'] = '|' + df.InChI
        cur_num += 1
CSV = CSV.sort_values(by = 'image_id').reset_index(drop = True)
CSV.to_csv("final_sub.csv", index = False)

# %% [markdown]
# # Normalize

# %%
# !while [ 1 ]; do python normalize_inchis.py && break; done
# Out:
# 0 number of predictions already normalized
# 7425it [00:09, 798.91it/s]/bin/bash: line 1:  9555 Segmentation fault      (core dumped) python normalize_inchis.py
# 7459 number of predictions already normalized
# 74556it [01:13, 1218.51it/s]/bin/bash: line 1:  9557 Segmentation fault      (core dumped) python normalize_inchis.py
# 82127 number of predictions already normalized
# 54466it [00:52, 1157.60it/s]/bin/bash: line 1:  9559 Segmentation fault      (core dumped) python normalize_inchis.py
# 136650 number of predictions already normalized
# 15006it [00:12, 1186.00it/s]/bin/bash: line 1:  9561 Segmentation fault      (core dumped) python normalize_inchis.py
# 151661 number of predictions already normalized
# 2054it [00:01, 1196.17it/s]/bin/bash: line 1:  9563 Segmentation fault      (core dumped) python normalize_inchis.py
# 153801 number of predictions already normalized
# 45885it [00:38, 1158.79it/s]/bin/bash: line 1:  9565 Segmentation fault      (core dumped) python normalize_inchis.py
# 199773 number of predictions already normalized
# 95290it [01:30, 1202.34it/s]/bin/bash: line 1:  9567 Segmentation fault      (core dumped) python normalize_inchis.py
# 295182 number of predictions already normalized
# 4894it [00:06, 835.47it/s]free(): invalid next size (fast)
# /bin/bash: line 1:  9569 Aborted                 (core dumped) python normalize_inchis.py
# 300128 number of predictions already normalized
# 34368it [00:28, 1193.44it/s]corrupted size vs. prev_size
# /bin/bash: line 1:  9571 Aborted                 (core dumped) python normalize_inchis.py
# 334510 number of predictions already normalized
# 25893it [00:21, 1174.79it/s]/bin/bash: line 1:  9573 Segmentation fault      (core dumped) python normalize_inchis.py
# 360514 number of predictions already normalized
# 3927it [00:03, 1191.69it/s]Traceback (most recent call last):
#   File "normalize_inchis.py", line 53, in <module>
#     inchi_norm, score = normalize_inchi(i)
#   File "normalize_inchis.py", line 13, in normalize_inchi
#     if mol is None:
# UnboundLocalError: local variable 'mol' referenced before assignment
# 4032it [00:03, 1202.23it/s]
# 364547 number of predictions already normalized
# 15020it [00:12, 1193.24it/s]/bin/bash: line 1:  9577 Segmentation fault      (core dumped) python normalize_inchis.py
# 379683 number of predictions already normalized
# 60662it [00:50, 1093.24it/s]/bin/bash: line 1:  9579 Segmentation fault      (core dumped) python normalize_inchis.py
# 440383 number of predictions already normalized
# 43180it [00:37, 786.95it/s] /bin/bash: line 1:  9581 Segmentation fault      (core dumped) python normalize_inchis.py
# 483571 number of predictions already normalized
# 57834it [00:55, 799.38it/s] /bin/bash: line 1:  9583 Segmentation fault      (core dumped) python normalize_inchis.py
# 541475 number of predictions already normalized
# 239it [00:00, 778.79it/s]/bin/bash: line 1:  9585 Segmentation fault      (core dumped) python normalize_inchis.py
# 541773 number of predictions already normalized
# 14180it [00:11, 1210.85it/s]/bin/bash: line 1:  9587 Segmentation fault      (core dumped) python normalize_inchis.py
# 556010 number of predictions already normalized
# 35877it [00:31, 792.50it/s] /bin/bash: line 1:  9589 Segmentation fault      (core dumped) python normalize_inchis.py
# 591949 number of predictions already normalized
# 16518it [00:20, 1172.82it/s]/bin/bash: line 1:  9591 Segmentation fault      (core dumped) python normalize_inchis.py
# 608583 number of predictions already normalized
# 13823it [00:11, 1198.82it/s]/bin/bash: line 1:  9593 Segmentation fault      (core dumped) python normalize_inchis.py
# 622437 number of predictions already normalized
# 17646it [00:14, 1172.58it/s]/bin/bash: line 1:  9595 Segmentation fault      (core dumped) python normalize_inchis.py
# 640150 number of predictions already normalized
# 149455it [02:33, 784.47it/s] /bin/bash: line 1:  9597 Segmentation fault      (core dumped) python normalize_inchis.py
# 789665 number of predictions already normalized
# 126232it [02:14, 1169.73it/s]/bin/bash: line 1:  9599 Segmentation fault      (core dumped) python normalize_inchis.py
# 915922 number of predictions already normalized
# 144045it [02:28, 802.34it/s] /bin/bash: line 1:  9601 Segmentation fault      (core dumped) python normalize_inchis.py
# 1060015 number of predictions already normalized
# 10063it [00:12, 803.40it/s]/bin/bash: line 1:  9603 Segmentation fault      (core dumped) python normalize_inchis.py
# 1070127 number of predictions already normalized
# 14150it [00:17, 773.46it/s]/bin/bash: line 1:  9605 Segmentation fault      (core dumped) python normalize_inchis.py
# 1084305 number of predictions already normalized
# 32973it [00:31, 1201.08it/s]/bin/bash: line 1:  9607 Segmentation fault      (core dumped) python normalize_inchis.py
# 1117302 number of predictions already normalized
# 81062it [01:13, 1226.08it/s]/bin/bash: line 1:  9609 Segmentation fault      (core dumped) python normalize_inchis.py
# 1198433 number of predictions already normalized
# 5851it [00:07, 790.17it/s]/bin/bash: line 1:  9611 Segmentation fault      (core dumped) python normalize_inchis.py
# 1204312 number of predictions already normalized
# 76718it [01:10, 811.39it/s] /bin/bash: line 1:  9613 Segmentation fault      (core dumped) python normalize_inchis.py
# 1281103 number of predictions already normalized
# 76163it [01:12, 1186.29it/s]/bin/bash: line 1:  9615 Segmentation fault      (core dumped) python normalize_inchis.py
# 1357361 number of predictions already normalized
# 1087it [00:00, 1176.24it/s]/bin/bash: line 1:  9617 Segmentation fault      (core dumped) python normalize_inchis.py
# 1358549 number of predictions already normalized
# 23827it [00:19, 1210.93it/s]/bin/bash: line 1:  9619 Segmentation fault      (core dumped) python normalize_inchis.py
# 1382407 number of predictions already normalized
# 58570it [00:54, 1242.95it/s]/bin/bash: line 1:  9621 Segmentation fault      (core dumped) python normalize_inchis.py
# 1441000 number of predictions already normalized
# 148382it [02:25, 1224.99it/s]/bin/bash: line 1:  9623 Segmentation fault      (core dumped) python normalize_inchis.py
# 1589410 number of predictions already normalized
# 26697it [00:33, 808.22it/s]

# %% [markdown]
# # Post process for final sub(InCHI-1)

# %%
csv = pd.read_csv("./submission.csv")
new_df = pd.DataFrame({'image_id': csv.image_id, 'InChI': csv.InChI_1})
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (2,3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
new_df.to_csv("./submission.csv", index = False)

# %%
pd.read_csv('./submission.csv').head()
# Out:
#        image_id                                              InChI
# 0  00000d2a601c  InChI=1S/C10H14BrN5S/c1-6-10(11)9(16(3)14-6)4-...
# 1  00001f7fc849  InChI=1S/C14H18ClN3/c1-2-7-16-9-13-10-17-14(18...
# 2  000037687605  InChI=1S/C16H13BrN2O/c1-11(20)12-6-7-13(9-18)1...
# 3  00004b6d55b6  InChI=1S/C14H19FN4O/c1-14(2,3)12-13(16)17-18-1...
# 4  00004df0fe53  InChI=1S/C9H12O2/c1-4-5-2-6-7(3-5)11-9(10)8(4)...
